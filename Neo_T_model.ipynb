# %%
import pandas as pd
dataset = pd.read_csv('26_gene.csv')

# %%
from pycaret.classification import *

# %%
clf1 = setup(data=dataset, target = 'outcome', session_id= 666)
# Out:
# <style type="text/css">
# #T_b86de_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b86de">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b86de_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b86de_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b86de_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b86de_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_b86de_row0_col1" class="data row0 col1" >666</td>
#     </tr>
#     <tr>
#       <th id="T_b86de_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b86de_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b86de_row1_col1" class="data row1 col1" >outcome</td>
#     </tr>
#     <tr>
#       <th id="T_b86de_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
xgb_model=create_model ('xgboost')
# Out:
# <style type="text/css">
# #T_065a4_row10_col0, #T_065a4_row10_col1, #T_065a4_row10_col2, #T_065a4_row10_col3, #T_065a4_row10_col4, #T_065a4_row10_col5, #T_065a4_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_065a4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_065a4_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_065a4_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_065a4_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_065a4_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_065a4_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_065a4_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_065a4_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_065a4_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
tuned_xgb = tune_model(xgb_model)
# Out:
# <style type="text/css">
# #T_a15b7_row10_col0, #T_a15b7_row10_col1, #T_a15b7_row10_col2, #T_a15b7_row10_col3, #T_a15b7_row10_col4, #T_a15b7_row10_col5, #T_a15b7_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_a15b7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a15b7_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_a15b7_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_a15b7_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_a15b7_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_a15b7_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_a15b7_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_a15b7_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a15b7_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
# %config InlineBackend.figure_format = 'svg'

# %%
plot_model(tuned_xgb, plot = 'pr')

# %%
predictions=predict_model(tuned_xgb)
# Out:
# <style type="text/css">
# </style>
# <table id="T_4a1f8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a1f8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4a1f8_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_4a1f8_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_4a1f8_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_4a1f8_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_4a1f8_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_4a1f8_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_4a1f8_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a1f8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4a1f8_row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
# ...

# %%
testset = pd.read_csv('Thisstudy.csv')

# %%
prediction=predict_model(tuned_xgb,data = testset)

# %%
prediction
# Out:
#       TNFRSF18      ENO1     STMN1      CD52     VCAM1      LMNA      RGS1  \
# 0    -0.815285  0.437897  0.670299 -0.610922 -0.489668  0.121531 -1.073984
# 1    -0.843983 -0.226926 -0.712853  0.352394 -0.546338  1.278486 -0.576380
# 2     1.464805  0.025313 -0.609791 -0.087056  7.419877 -1.013616  0.362157
# 3    -0.838398 -0.205714 -0.660349  0.902371 -0.538708 -0.545486 -0.556605
# 4     2.779088 -1.036092 -1.033895 -0.052891  3.611514 -0.199726 -0.308988
# ...        ...       ...       ...       ...       ...       ...       ...
# 5952 -1.291903  0.046172  3.883067  1.243176 -0.823002 -0.550760 -0.440167
# 5953  0.912407  0.767900  0.608492  0.275108  0.427700 -0.904449  0.622062
# 5954 -1.041418 -0.597105  5.394139 -0.733825 -0.758981 -0.701062  0.140327
# 5955 -1.213615  8.496428 -1.796482  1.776601 -0.867495 -0.523292 -1.067384
# 5956 -1.366498  0.035044  6.805717  1.345523 -1.002900 -0.505961 -0.340457
#
# ...

# %%
prediction.to_csv('333.csv')

# %%
interpret_model(tuned_xgb)
# Out:
# /root/miniconda3/envs/pycaret/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /root/miniconda3/envs/pycaret/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /root/miniconda3/envs/pycaret/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# ...

# %%
evaluate_model(tuned_xgb)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
tuned_xgb = load_model('Final_Neo-T_prediction_model')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
tuned_xgb
# Out:
# Pipeline(steps=[('dtypes',
#                  DataTypes_Auto_infer(ml_usecase='classification',
#                                       target='outcome')),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strategy='mean',
#                                 target_variable=None)),
#                 ('new_levels1',
#                  New_Catagorical_Levels_in_TestData(replacement_strategy='least '
#                                                                          'frequent',
#                                                     tar...
#                                gamma=0, gpu_id=-1, importance_type=None,
#                                interaction_constraints='', learning_rate=0.15,
#                                max_delta_step=0, max_depth=7,
# ...

# %%
testset = pd.read_csv('z-score-total.csv')

# %%
prediction=predict_model(tuned_xgb,data = testset)

# %%
prediction.to_csv('333.csv')
